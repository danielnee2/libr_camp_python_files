# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
print ('UpShot of notebook')
# Out:
# UpShot of notebook

# %% [markdown]
# ## This is mark down cell
#
#    this is its text
#
#    allow formating

# %%
surveys_df = pd.read_csv("surveys.csv")

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
type (surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Panda data frame:
# allow class and methods

# %%
# check data type within this class

surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.head() # top five rows
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
# Look at the column names
surveys_df.columns.values
# Out:
# numpy.ndarray

# %%
type(surveys_df.columns.values)
# Out:
# numpy.ndarray

# %%
pd.unique(surveys_df['species_id']) # showing the unique species within
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
plot_names = pd.unique(surveys_df['species_id'])

# %%
len(plot_names) # statistics
# Out:
# 49

# %%
surveys_df['weight'].describe() # do a fast statistics
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
type (surveys_df['weight'].describe() )
# Out:
# pandas.core.series.Series

# %%
# Group data by sex
sp_count = surveys_df.groupby('species_id')['record_id'].count()

# %%
#print(sp_count)
sp_count.plot(kind = 'bar')

# %%
# Group data by sex
sorted_sex = surveys_df.groupby('sex')

# %% [raw]
# # summary statistics for all numeric columns by sex
# sorted_sex.describe()

# %%
# provide the mean for each numeric column by sex
sorted_sex.count()
# Out:
#      record_id  month    day   year  plot_id  species_id  hindfoot_length  \
# sex
# F        15690  15690  15690  15690    15690       15690            14894
# M        17348  17348  17348  17348    17348       17348            16476
#
#      weight
# sex
# F     15303
# M     16879

# %%
# exercise : Plot average weight of species per plot

# %%
sorted_species = surveys_df.groupby('plot_id')

# %%
sorted_species.describe();

# %%
sorted_species['weight'].mean().plot(kind = 'bar')

# %%
sorted_df = sorted_species['weight'].mean()[:]

# %%
pd.isnull(surveys_df)
# Out:
#       record_id  month    day   year plot_id species_id    sex  \
# 0         False  False  False  False   False      False  False
# 1         False  False  False  False   False      False  False
# 2         False  False  False  False   False      False  False
# 3         False  False  False  False   False      False  False
# 4         False  False  False  False   False      False  False
# 5         False  False  False  False   False      False  False
# 6         False  False  False  False   False      False  False
# 7         False  False  False  False   False      False  False
# 8         False  False  False  False   False      False  False
# 9         False  False  False  False   False      False  False
# 10        False  False  False  False   False      False  False
# 11        False  False  False  False   False      False  False
# 12        False  False  False  False   False      False  False
# 13        False  False  False  False   False      False   True
# ...

# %%
surveys_df[pd.isnull(surveys_df).any(axis=1)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
len(surveys_df[pd.notnull(surveys_df['weight'])]['weight'])
# Out:
# 32283

# %%
len(surveys_df[pd.notnull(surveys_df['weight'])])
# Out:
# 32283

# %%
len(surveys_df[pd.isnull(surveys_df['weight'])])
# Out:
# 3266

# %%
df1 = surveys_df.copy()

# %%
df1['weight'] = df1['weight'].fillna(0)

# %%
df1['weight'].sum()
# Out:
# 1377594.0

# %%
len(surveys_df[surveys_df.weight >100])
# Out:
# 2970

# %%
species_df = pd.read_csv("species.csv")

# %%
print(species_df)
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
# read in first 10 lines of surveys table
survey_sub = surveys_df.head(10)

# %%
survey_sub_last10 = surveys_df.tail(10)

# %%
# stack the DataFrames on top of each other
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)

# place the DataFrames side by side
horizontal_stack = pd.concat([survey_sub, survey_sub_last10], axis=1)

# %%
vertical_stack
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# ...

# %%
horizontal_stack
# Out:
#        record_id  month   day    year  plot_id species_id  sex  \
# 0            1.0    7.0  16.0  1977.0      2.0         NL    M
# 1            2.0    7.0  16.0  1977.0      3.0         NL    M
# 2            3.0    7.0  16.0  1977.0      2.0         DM    F
# 3            4.0    7.0  16.0  1977.0      7.0         DM    M
# 4            5.0    7.0  16.0  1977.0      3.0         DM    M
# 5            6.0    7.0  16.0  1977.0      1.0         PF    M
# 6            7.0    7.0  16.0  1977.0      2.0         PE    F
# 7            8.0    7.0  16.0  1977.0      1.0         DM    M
# 8            9.0    7.0  16.0  1977.0      1.0         DM    F
# 9           10.0    7.0  16.0  1977.0      6.0         PF    F
# 35539        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35540        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35541        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35542        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# ...

# %%
# Write DataFrame to CSV
vertical_stack.to_csv('out.csv')
